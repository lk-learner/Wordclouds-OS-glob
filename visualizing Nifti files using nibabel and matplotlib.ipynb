# %%
from nilearn import plotting
# Out:
# C:\Users\lavy_\Anaconda3\lib\site-packages\dicom\__init__.py:53: UserWarning:
# This code is using an older version of pydicom, which is no longer
# maintained as of Jan 2017.  You can access the new pydicom features and API
# by installing `pydicom` from PyPI.
# See 'Transitioning to pydicom 1.x' section at pydicom.readthedocs.org
# for more information.
#
#   warnings.warn(msg)

# %%
plotting.plot_glass_brain('volume-0.nii.gz')
# Out:
# C:\Users\lavy_\Anaconda3\lib\site-packages\nilearn\plotting\displays.py:780: UserWarning: empty mask
#   get_mask_bounds(new_img_like(img, not_mask, affine))

# %%
import nibabel as nib

# %%
img = nib.load('volume-0.nii.gz')

# %%
data = img.get_fdata()

# %%
data.shape
# Out:
# (512, 512, 75)

# %%
import matplotlib.pyplot as plt
def show_slices(slices):
   """ Function to display row of image slices """
   fig, axes = plt.subplots(1, len(slices))
   for i, slice in enumerate(slices):
       axes[i].imshow(slice.T, cmap="gray", origin="lower")

slice_1 = data[26, :, :]
slice_2 = data[:, 30, :]
slice_3 = data[:, :, 16]
show_slices([slice_1, slice_2, slice_3])
plt.suptitle("Center slices for liver image")
# Out:
# Text(0.5,0.98,'Center slices for liver image')

# %%
img1 = nib.load('volume-14.nii.gz')
data1 = img1.get_fdata()
data1.shape
(57, 67, 56)

show_slices([data[28, :, :], data[:, 33, :], data[:, :, 16]])
plt.suptitle("Center slices for liver image")
# Out:
# Text(0.5,0.98,'Center slices for liver image')
